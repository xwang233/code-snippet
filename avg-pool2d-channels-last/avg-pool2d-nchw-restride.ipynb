# %%
import torch 
import time 

print(torch.__version__)

dtype=torch.half
warm_up = 1000 
n_iter = 1000

fs = [] 
bs = []

for n in (1, 32, 64): 
    for c in (1, 32, 64): 
        for h in (14, 28, 56, 128, 256): 
            w = h
            for ks in (2, 3, 5, 7): 
                torch.cuda.empty_cache() 

                print(f'n {n}, c {c}, h {h}, w {w}, ks {ks}', end='\t')

                a = torch.randn(n, c, h, w, dtype=dtype, device='cuda').contiguous(memory_format=torch.channels_last)
                ref_a = a.clone().contiguous() 

                a.requires_grad_() 
                ref_a.requires_grad_() 

                pool = torch.nn.AvgPool2d(ks).cuda()
                ref_pool = torch.nn.AvgPool2d(ks).cuda()

                out = pool(a)
                ref_out = ref_pool(ref_a)

                grad = torch.ones_like(out)
                ref_grad = grad.clone().contiguous()
                
                out.backward(grad, retain_graph=True)
                ref_out.backward(ref_grad, retain_graph=True)

                assert((out==ref_out).all().item())
                assert((a.grad==ref_a.grad).all().item())

                ########## warm up ##########
                for _ in range(warm_up): 
                    out = pool(a)
                    ref_out = ref_pool(ref_a)
                    out.backward(grad, retain_graph=True)
                    ref_out.backward(grad, retain_graph=True)

                ########## channels_last forward 1 ##########
                torch.cuda.synchronize() 
                ts = time.time() 

                for _ in range(n_iter): 
                    out = pool(a)
                    torch.cuda.synchronize() 

                torch.cuda.synchronize() 
                t_channels_last_forward_1 = (time.time() - ts) / n_iter

                ########## contiguous forward ##########
                torch.cuda.synchronize()
                ts = time.time() 

                for _ in range(n_iter): 
                    ref_out = ref_pool(ref_a)
                    torch.cuda.synchronize() 

                torch.cuda.synchronize() 
                t_contiguous_forward = (time.time() - ts) / n_iter
                
                ########## channels_last forward 2 ##########
                torch.cuda.synchronize() 
                ts = time.time() 

                for _ in range(n_iter): 
                    out = pool(a)
                    torch.cuda.synchronize() 

                torch.cuda.synchronize() 
                t_channels_last_forward_2 = (time.time() - ts) / n_iter

                ########## channels_last backward 1 ##########
                torch.cuda.synchronize() 
                ts = time.time() 

                for _ in range(n_iter): 
                    out.backward(grad, retain_graph=True)
                    torch.cuda.synchronize() 

                torch.cuda.synchronize() 
                t_channels_last_backward_1 = (time.time() - ts) / n_iter

                ########## contiguous backward ##########
                torch.cuda.synchronize()
                ts = time.time() 

                for _ in range(n_iter): 
                    ref_out.backward(ref_grad, retain_graph=True)
                    torch.cuda.synchronize() 

                torch.cuda.synchronize() 
                t_contiguous_backward = (time.time() - ts) / n_iter
                
                ########## channels_last backward 2 ##########
                torch.cuda.synchronize() 
                ts = time.time() 

                for _ in range(n_iter): 
                    out.backward(grad, retain_graph=True)
                    torch.cuda.synchronize() 

                torch.cuda.synchronize() 
                t_channels_last_backward_2 = (time.time() - ts) / n_iter
                
                ########## stat ##########
                t_channels_last_forward = 0.5 * (t_channels_last_forward_1 + t_channels_last_forward_2)
                t_channels_last_backward = 0.5 * (t_channels_last_backward_1 + t_channels_last_backward_2)
                
                forward_speedup = t_contiguous_forward/t_channels_last_forward
                backward_speedup = t_contiguous_backward/t_channels_last_backward
                fs.append(forward_speedup)
                bs.append(backward_speedup)
                
                ########## print ##########
                print('channels_last speedup, forward {:.3f}, backward {:.3f}'.format(
                    forward_speedup, backward_speedup
                ))
# Out:
# 1.6.0a0+dc4d888
# n 1, c 1, h 14, w 14, ks 2	channels_last speedup, forward 0.985, backward 0.939
# n 1, c 1, h 14, w 14, ks 3	channels_last speedup, forward 0.956, backward 1.003
# n 1, c 1, h 14, w 14, ks 5	channels_last speedup, forward 0.950, backward 1.027
# n 1, c 1, h 14, w 14, ks 7	channels_last speedup, forward 0.950, backward 1.031
# n 1, c 1, h 28, w 28, ks 2	channels_last speedup, forward 0.949, backward 1.039
# n 1, c 1, h 28, w 28, ks 3	channels_last speedup, forward 0.932, backward 1.034
# n 1, c 1, h 28, w 28, ks 5	channels_last speedup, forward 0.951, backward 1.026
# n 1, c 1, h 28, w 28, ks 7	channels_last speedup, forward 0.956, backward 1.029
# n 1, c 1, h 56, w 56, ks 2	channels_last speedup, forward 0.943, backward 1.027
# n 1, c 1, h 56, w 56, ks 3	channels_last speedup, forward 0.955, backward 1.027
# n 1, c 1, h 56, w 56, ks 5	channels_last speedup, forward 0.944, backward 1.037
# n 1, c 1, h 56, w 56, ks 7	channels_last speedup, forward 0.904, backward 1.034
# n 1, c 1, h 128, w 128, ks 2	channels_last speedup, forward 0.937, backward 1.025
# n 1, c 1, h 128, w 128, ks 3	channels_last speedup, forward 0.951, backward 1.002
# n 1, c 1, h 128, w 128, ks 5	channels_last speedup, forward 0.955, backward 1.031
# n 1, c 1, h 128, w 128, ks 7	channels_last speedup, forward 0.954, backward 1.019
# n 1, c 1, h 256, w 256, ks 2	channels_last speedup, forward 0.944, backward 1.034
# n 1, c 1, h 256, w 256, ks 3	channels_last speedup, forward 0.945, backward 1.038
# n 1, c 1, h 256, w 256, ks 5	channels_last speedup, forward 0.942, backward 1.030
# n 1, c 1, h 256, w 256, ks 7	channels_last speedup, forward 0.950, backward 1.034
# n 1, c 32, h 14, w 14, ks 2	channels_last speedup, forward 0.641, backward 0.868
# n 1, c 32, h 14, w 14, ks 3	channels_last speedup, forward 0.641, backward 0.869
# n 1, c 32, h 14, w 14, ks 5	channels_last speedup, forward 0.635, backward 0.850
# n 1, c 32, h 14, w 14, ks 7	channels_last speedup, forward 0.649, backward 0.853
# n 1, c 32, h 28, w 28, ks 2	channels_last speedup, forward 0.643, backward 0.871
# n 1, c 32, h 28, w 28, ks 3	channels_last speedup, forward 0.631, backward 0.863
# n 1, c 32, h 28, w 28, ks 5	channels_last speedup, forward 0.635, backward 0.868
# n 1, c 32, h 28, w 28, ks 7	channels_last speedup, forward 0.631, backward 0.867
# n 1, c 32, h 56, w 56, ks 2	channels_last speedup, forward 0.648, backward 0.875
# n 1, c 32, h 56, w 56, ks 3	channels_last speedup, forward 0.635, backward 0.867
# n 1, c 32, h 56, w 56, ks 5	channels_last speedup, forward 0.639, backward 0.881
# n 1, c 32, h 56, w 56, ks 7	channels_last speedup, forward 0.640, backward 0.866
# n 1, c 32, h 128, w 128, ks 2	channels_last speedup, forward 0.630, backward 0.873
# n 1, c 32, h 128, w 128, ks 3	channels_last speedup, forward 0.632, backward 0.872
# n 1, c 32, h 128, w 128, ks 5	channels_last speedup, forward 0.642, backward 0.852
# n 1, c 32, h 128, w 128, ks 7	channels_last speedup, forward 0.637, backward 0.866
# n 1, c 32, h 256, w 256, ks 2	channels_last speedup, forward 0.388, backward 0.681
# n 1, c 32, h 256, w 256, ks 3	channels_last speedup, forward 0.345, backward 0.686
# n 1, c 32, h 256, w 256, ks 5	channels_last speedup, forward 0.343, backward 0.676
# n 1, c 32, h 256, w 256, ks 7	channels_last speedup, forward 0.351, backward 0.677
# n 1, c 64, h 14, w 14, ks 2	channels_last speedup, forward 0.658, backward 0.885
# n 1, c 64, h 14, w 14, ks 3	channels_last speedup, forward 0.634, backward 0.767
# n 1, c 64, h 14, w 14, ks 5	channels_last speedup, forward 0.634, backward 0.863
# n 1, c 64, h 14, w 14, ks 7	channels_last speedup, forward 0.635, backward 0.879
# n 1, c 64, h 28, w 28, ks 2	channels_last speedup, forward 0.644, backward 0.875
# n 1, c 64, h 28, w 28, ks 3	channels_last speedup, forward 0.635, backward 0.867
# n 1, c 64, h 28, w 28, ks 5	channels_last speedup, forward 0.635, backward 0.875
# n 1, c 64, h 28, w 28, ks 7	channels_last speedup, forward 0.648, backward 0.873
# n 1, c 64, h 56, w 56, ks 2	channels_last speedup, forward 0.639, backward 0.862
# n 1, c 64, h 56, w 56, ks 3	channels_last speedup, forward 0.650, backward 0.876
# n 1, c 64, h 56, w 56, ks 5	channels_last speedup, forward 0.676, backward 0.806
# n 1, c 64, h 56, w 56, ks 7	channels_last speedup, forward 0.633, backward 0.795
# n 1, c 64, h 128, w 128, ks 2	channels_last speedup, forward 0.586, backward 0.756
# n 1, c 64, h 128, w 128, ks 3	channels_last speedup, forward 0.575, backward 0.725
# n 1, c 64, h 128, w 128, ks 5	channels_last speedup, forward 0.586, backward 0.705
# n 1, c 64, h 128, w 128, ks 7	channels_last speedup, forward 0.583, backward 0.727
# n 1, c 64, h 256, w 256, ks 2	channels_last speedup, forward 0.115, backward 0.363
# n 1, c 64, h 256, w 256, ks 3	channels_last speedup, forward 0.088, backward 0.358
# n 1, c 64, h 256, w 256, ks 5	channels_last speedup, forward 0.079, backward 0.355
# n 1, c 64, h 256, w 256, ks 7	channels_last speedup, forward 0.079, backward 0.351
# n 32, c 1, h 14, w 14, ks 2	channels_last speedup, forward 0.928, backward 0.984
# n 32, c 1, h 14, w 14, ks 3	channels_last speedup, forward 0.949, backward 1.040
# n 32, c 1, h 14, w 14, ks 5	channels_last speedup, forward 0.960, backward 1.037
# n 32, c 1, h 14, w 14, ks 7	channels_last speedup, forward 0.942, backward 1.066
# n 32, c 1, h 28, w 28, ks 2	channels_last speedup, forward 0.930, backward 1.028
# n 32, c 1, h 28, w 28, ks 3	channels_last speedup, forward 0.935, backward 1.037
# n 32, c 1, h 28, w 28, ks 5	channels_last speedup, forward 0.935, backward 1.026
# n 32, c 1, h 28, w 28, ks 7	channels_last speedup, forward 0.940, backward 1.023
# n 32, c 1, h 56, w 56, ks 2	channels_last speedup, forward 0.950, backward 1.034
# n 32, c 1, h 56, w 56, ks 3	channels_last speedup, forward 0.929, backward 1.025
# n 32, c 1, h 56, w 56, ks 5	channels_last speedup, forward 0.922, backward 1.032
# n 32, c 1, h 56, w 56, ks 7	channels_last speedup, forward 0.948, backward 1.026
# n 32, c 1, h 128, w 128, ks 2	channels_last speedup, forward 0.941, backward 1.023
# n 32, c 1, h 128, w 128, ks 3	channels_last speedup, forward 0.942, backward 0.992
# n 32, c 1, h 128, w 128, ks 5	channels_last speedup, forward 0.950, backward 1.029
# n 32, c 1, h 128, w 128, ks 7	channels_last speedup, forward 0.953, backward 1.036
# n 32, c 1, h 256, w 256, ks 2	channels_last speedup, forward 0.993, backward 1.004
# n 32, c 1, h 256, w 256, ks 3	channels_last speedup, forward 0.954, backward 1.024
# n 32, c 1, h 256, w 256, ks 5	channels_last speedup, forward 0.947, backward 0.995
# n 32, c 1, h 256, w 256, ks 7	channels_last speedup, forward 0.950, backward 1.005
# n 32, c 32, h 14, w 14, ks 2	channels_last speedup, forward 0.641, backward 0.883
# n 32, c 32, h 14, w 14, ks 3	channels_last speedup, forward 0.644, backward 0.861
# n 32, c 32, h 14, w 14, ks 5	channels_last speedup, forward 0.651, backward 0.908
# n 32, c 32, h 14, w 14, ks 7	channels_last speedup, forward 0.636, backward 0.879
# n 32, c 32, h 28, w 28, ks 2	channels_last speedup, forward 0.638, backward 0.810
# n 32, c 32, h 28, w 28, ks 3	channels_last speedup, forward 0.625, backward 0.805
# n 32, c 32, h 28, w 28, ks 5	channels_last speedup, forward 0.642, backward 0.817
# n 32, c 32, h 28, w 28, ks 7	channels_last speedup, forward 0.636, backward 0.827
# n 32, c 32, h 56, w 56, ks 2	channels_last speedup, forward 0.524, backward 0.692
# n 32, c 32, h 56, w 56, ks 3	channels_last speedup, forward 0.457, backward 0.702
# n 32, c 32, h 56, w 56, ks 5	channels_last speedup, forward 0.437, backward 0.701
# n 32, c 32, h 56, w 56, ks 7	channels_last speedup, forward 0.427, backward 0.710
# n 32, c 32, h 128, w 128, ks 2	channels_last speedup, forward 0.401, backward 0.788
# n 32, c 32, h 128, w 128, ks 3	channels_last speedup, forward 0.291, backward 0.789
# n 32, c 32, h 128, w 128, ks 5	channels_last speedup, forward 0.255, backward 0.785
# n 32, c 32, h 128, w 128, ks 7	channels_last speedup, forward 0.239, backward 0.784
# n 32, c 32, h 256, w 256, ks 2	channels_last speedup, forward 0.245, backward 0.640
# n 32, c 32, h 256, w 256, ks 3	channels_last speedup, forward 0.160, backward 0.638
# n 32, c 32, h 256, w 256, ks 5	channels_last speedup, forward 0.122, backward 0.637
# n 32, c 32, h 256, w 256, ks 7	channels_last speedup, forward 0.117, backward 0.635
# n 32, c 64, h 14, w 14, ks 2	channels_last speedup, forward 0.635, backward 0.875
# n 32, c 64, h 14, w 14, ks 3	channels_last speedup, forward 0.628, backward 0.871
# n 32, c 64, h 14, w 14, ks 5	channels_last speedup, forward 0.634, backward 0.865
# n 32, c 64, h 14, w 14, ks 7	channels_last speedup, forward 0.621, backward 0.872
# n 32, c 64, h 28, w 28, ks 2	channels_last speedup, forward 0.440, backward 0.761
# n 32, c 64, h 28, w 28, ks 3	channels_last speedup, forward 0.453, backward 0.760
# n 32, c 64, h 28, w 28, ks 5	channels_last speedup, forward 0.476, backward 0.755
# n 32, c 64, h 28, w 28, ks 7	channels_last speedup, forward 0.459, backward 0.753
# n 32, c 64, h 56, w 56, ks 2	channels_last speedup, forward 0.369, backward 0.727
# n 32, c 64, h 56, w 56, ks 3	channels_last speedup, forward 0.291, backward 0.726
# n 32, c 64, h 56, w 56, ks 5	channels_last speedup, forward 0.270, backward 0.723
# n 32, c 64, h 56, w 56, ks 7	channels_last speedup, forward 0.272, backward 0.727
# n 32, c 64, h 128, w 128, ks 2	channels_last speedup, forward 0.293, backward 0.694
# n 32, c 64, h 128, w 128, ks 3	channels_last speedup, forward 0.196, backward 0.693
# n 32, c 64, h 128, w 128, ks 5	channels_last speedup, forward 0.157, backward 0.691
# n 32, c 64, h 128, w 128, ks 7	channels_last speedup, forward 0.150, backward 0.689
# n 32, c 64, h 256, w 256, ks 2	channels_last speedup, forward 0.085, backward 0.338
# n 32, c 64, h 256, w 256, ks 3	channels_last speedup, forward 0.051, backward 0.337
# n 32, c 64, h 256, w 256, ks 5	channels_last speedup, forward 0.037, backward 0.335
# n 32, c 64, h 256, w 256, ks 7	channels_last speedup, forward 0.036, backward 0.333
# n 64, c 1, h 14, w 14, ks 2	channels_last speedup, forward 0.937, backward 0.987
# n 64, c 1, h 14, w 14, ks 3	channels_last speedup, forward 0.942, backward 1.032
# n 64, c 1, h 14, w 14, ks 5	channels_last speedup, forward 0.957, backward 1.030
# n 64, c 1, h 14, w 14, ks 7	channels_last speedup, forward 0.950, backward 1.031
# n 64, c 1, h 28, w 28, ks 2	channels_last speedup, forward 0.942, backward 1.037
# n 64, c 1, h 28, w 28, ks 3	channels_last speedup, forward 0.935, backward 1.038
# n 64, c 1, h 28, w 28, ks 5	channels_last speedup, forward 0.941, backward 1.032
# n 64, c 1, h 28, w 28, ks 7	channels_last speedup, forward 0.957, backward 1.031
# n 64, c 1, h 56, w 56, ks 2	channels_last speedup, forward 0.951, backward 1.027
# n 64, c 1, h 56, w 56, ks 3	channels_last speedup, forward 0.942, backward 1.018
# n 64, c 1, h 56, w 56, ks 5	channels_last speedup, forward 0.966, backward 1.030
# n 64, c 1, h 56, w 56, ks 7	channels_last speedup, forward 0.960, backward 1.037
# n 64, c 1, h 128, w 128, ks 2	channels_last speedup, forward 0.944, backward 1.035
# n 64, c 1, h 128, w 128, ks 3	channels_last speedup, forward 0.957, backward 1.021
# n 64, c 1, h 128, w 128, ks 5	channels_last speedup, forward 0.960, backward 1.045
# n 64, c 1, h 128, w 128, ks 7	channels_last speedup, forward 0.937, backward 1.025
# n 64, c 1, h 256, w 256, ks 2	channels_last speedup, forward 1.000, backward 0.995
# n 64, c 1, h 256, w 256, ks 3	channels_last speedup, forward 0.995, backward 0.999
# n 64, c 1, h 256, w 256, ks 5	channels_last speedup, forward 0.996, backward 0.999
# n 64, c 1, h 256, w 256, ks 7	channels_last speedup, forward 0.997, backward 1.017
# n 64, c 32, h 14, w 14, ks 2	channels_last speedup, forward 0.636, backward 0.861
# n 64, c 32, h 14, w 14, ks 3	channels_last speedup, forward 0.627, backward 0.872
# n 64, c 32, h 14, w 14, ks 5	channels_last speedup, forward 0.644, backward 0.880
# n 64, c 32, h 14, w 14, ks 7	channels_last speedup, forward 0.634, backward 0.866
# n 64, c 32, h 28, w 28, ks 2	channels_last speedup, forward 0.526, backward 0.824
# n 64, c 32, h 28, w 28, ks 3	channels_last speedup, forward 0.548, backward 0.829
# n 64, c 32, h 28, w 28, ks 5	channels_last speedup, forward 0.577, backward 0.824
# n 64, c 32, h 28, w 28, ks 7	channels_last speedup, forward 0.545, backward 0.829
# n 64, c 32, h 56, w 56, ks 2	channels_last speedup, forward 0.483, backward 0.813
# n 64, c 32, h 56, w 56, ks 3	channels_last speedup, forward 0.398, backward 0.810
# n 64, c 32, h 56, w 56, ks 5	channels_last speedup, forward 0.368, backward 0.813
# n 64, c 32, h 56, w 56, ks 7	channels_last speedup, forward 0.374, backward 0.812
# n 64, c 32, h 128, w 128, ks 2	channels_last speedup, forward 0.392, backward 0.781
# n 64, c 32, h 128, w 128, ks 3	channels_last speedup, forward 0.274, backward 0.779
# n 64, c 32, h 128, w 128, ks 5	channels_last speedup, forward 0.223, backward 0.779
# n 64, c 32, h 128, w 128, ks 7	channels_last speedup, forward 0.214, backward 0.778
# n 64, c 32, h 256, w 256, ks 2	channels_last speedup, forward 0.243, backward 0.636
# n 64, c 32, h 256, w 256, ks 3	channels_last speedup, forward 0.157, backward 0.636
# n 64, c 32, h 256, w 256, ks 5	channels_last speedup, forward 0.117, backward 0.633
# n 64, c 32, h 256, w 256, ks 7	channels_last speedup, forward 0.113, backward 0.632
# n 64, c 64, h 14, w 14, ks 2	channels_last speedup, forward 0.575, backward 0.712
# n 64, c 64, h 14, w 14, ks 3	channels_last speedup, forward 0.635, backward 0.737
# n 64, c 64, h 14, w 14, ks 5	channels_last speedup, forward 0.636, backward 0.758
# n 64, c 64, h 14, w 14, ks 7	channels_last speedup, forward 0.595, backward 0.760
# n 64, c 64, h 28, w 28, ks 2	channels_last speedup, forward 0.405, backward 0.627
# n 64, c 64, h 28, w 28, ks 3	channels_last speedup, forward 0.363, backward 0.629
# n 64, c 64, h 28, w 28, ks 5	channels_last speedup, forward 0.335, backward 0.619
# n 64, c 64, h 28, w 28, ks 7	channels_last speedup, forward 0.361, backward 0.612
# n 64, c 64, h 56, w 56, ks 2	channels_last speedup, forward 0.332, backward 0.732
# n 64, c 64, h 56, w 56, ks 3	channels_last speedup, forward 0.241, backward 0.731
# n 64, c 64, h 56, w 56, ks 5	channels_last speedup, forward 0.216, backward 0.726
# n 64, c 64, h 56, w 56, ks 7	channels_last speedup, forward 0.215, backward 0.726
# n 64, c 64, h 128, w 128, ks 2	channels_last speedup, forward 0.287, backward 0.689
# n 64, c 64, h 128, w 128, ks 3	channels_last speedup, forward 0.188, backward 0.687
# n 64, c 64, h 128, w 128, ks 5	channels_last speedup, forward 0.146, backward 0.685
# n 64, c 64, h 128, w 128, ks 7	channels_last speedup, forward 0.140, backward 0.683
# n 64, c 64, h 256, w 256, ks 2	channels_last speedup, forward 0.085, backward 0.336
# n 64, c 64, h 256, w 256, ks 3	channels_last speedup, forward 0.051, backward 0.336
# n 64, c 64, h 256, w 256, ks 5	channels_last speedup, forward 0.036, backward 0.333
# n 64, c 64, h 256, w 256, ks 7	channels_last speedup, forward 0.035, backward 0.332

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.distplot(fs, bins=40)
plt.show() 

sns.distplot(bs, bins=40)
plt.show()
