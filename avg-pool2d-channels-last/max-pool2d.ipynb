# %%
import torch 
import time 

print(torch.__version__)

dtype=torch.half
warm_up = 100 
n_iter = 1000

fs = [] 
bs = []

for n in (1, 32, 64): 
    for c in (1, 32, 64): 
        for h in (14, 28, 56, 128, 256): 
            w = h
            for ks in (2, 3, 5, 7): 
                torch.cuda.empty_cache() 

                print(f'n {n}, c {c}, h {h}, w {w}, ks {ks}', end='\t')

                a = torch.randn(n, c, h, w, dtype=dtype, device='cuda').contiguous(memory_format=torch.channels_last)
                ref_a = a.clone().contiguous() 

                a.requires_grad_() 
                ref_a.requires_grad_() 

                pool = torch.nn.MaxPool2d(ks).cuda()
                ref_pool = torch.nn.MaxPool2d(ks).cuda()

                out = pool(a)
                ref_out = ref_pool(ref_a)

                grad = torch.ones_like(out)
                out.backward(grad, retain_graph=True)
                ref_out.backward(grad, retain_graph=True)

                assert((out==ref_out).all().item())
                assert((a.grad==ref_a.grad).all().item())

                ########## warm up ##########
                for _ in range(warm_up): 
                    out = pool(a)
                    ref_out = ref_pool(ref_a)
                    out.backward(grad, retain_graph=True)
                    ref_out.backward(grad, retain_graph=True)

                ########## channels_last forward ##########
                torch.cuda.synchronize() 
                ts = time.time() 

                for _ in range(n_iter): 
                    out = pool(a)
                    torch.cuda.synchronize() 

                t_channels_last_forward = (time.time() - ts) / n_iter

                ########## contiguous forward ##########
                torch.cuda.synchronize()
                ts = time.time() 

                for _ in range(n_iter): 
                    ref_out = ref_pool(ref_a)
                    torch.cuda.synchronize() 

                t_contiguous_forward = (time.time() - ts) / n_iter

                ########## channels_last backward ##########
                torch.cuda.synchronize() 
                ts = time.time() 

                for _ in range(n_iter): 
                    out.backward(grad, retain_graph=True)
                    torch.cuda.synchronize() 

                t_channels_last_backward = (time.time() - ts) / n_iter

                ########## contiguous backward ##########
                torch.cuda.synchronize()
                ts = time.time() 

                for _ in range(n_iter): 
                    ref_out.backward(grad, retain_graph=True)
                    torch.cuda.synchronize() 

                t_contiguous_backward = (time.time() - ts) / n_iter
                
                ########## stat ##########
                forward_speedup = t_contiguous_forward/t_channels_last_forward
                backward_speedup = t_contiguous_backward/t_channels_last_backward
                fs.append(forward_speedup)
                bs.append(backward_speedup)
                
                ########## print ##########
                print('channels_last speedup, forward {:.3f}, backward {:.3f}'.format(
                    forward_speedup, backward_speedup
                ))
# Out:
# 1.6.0a0+0a8fd79
# n 1, c 1, h 14, w 14, ks 2	channels_last speedup, forward 0.974, backward 1.005
# n 1, c 1, h 14, w 14, ks 3	channels_last speedup, forward 0.993, backward 1.065
# n 1, c 1, h 14, w 14, ks 5	channels_last speedup, forward 0.858, backward 1.092
# n 1, c 1, h 14, w 14, ks 7	channels_last speedup, forward 0.878, backward 1.040
# n 1, c 1, h 28, w 28, ks 2	channels_last speedup, forward 0.869, backward 1.052
# n 1, c 1, h 28, w 28, ks 3	channels_last speedup, forward 0.875, backward 1.101
# n 1, c 1, h 28, w 28, ks 5	channels_last speedup, forward 0.872, backward 1.041
# n 1, c 1, h 28, w 28, ks 7	channels_last speedup, forward 0.863, backward 1.043
# n 1, c 1, h 56, w 56, ks 2	channels_last speedup, forward 0.871, backward 1.034
# n 1, c 1, h 56, w 56, ks 3	channels_last speedup, forward 0.880, backward 0.971
# n 1, c 1, h 56, w 56, ks 5	channels_last speedup, forward 0.854, backward 1.044
# n 1, c 1, h 56, w 56, ks 7	channels_last speedup, forward 0.867, backward 1.049
# n 1, c 1, h 128, w 128, ks 2	channels_last speedup, forward 0.872, backward 1.045
# n 1, c 1, h 128, w 128, ks 3	channels_last speedup, forward 0.870, backward 1.050
# n 1, c 1, h 128, w 128, ks 5	channels_last speedup, forward 0.868, backward 0.971
# n 1, c 1, h 128, w 128, ks 7	channels_last speedup, forward 0.879, backward 1.022
# n 1, c 1, h 256, w 256, ks 2	channels_last speedup, forward 0.864, backward 1.048
# n 1, c 1, h 256, w 256, ks 3	channels_last speedup, forward 0.872, backward 1.042
# n 1, c 1, h 256, w 256, ks 5	channels_last speedup, forward 0.872, backward 1.040
# n 1, c 1, h 256, w 256, ks 7	channels_last speedup, forward 0.876, backward 1.053
# n 1, c 32, h 14, w 14, ks 2	channels_last speedup, forward 0.840, backward 1.173
# n 1, c 32, h 14, w 14, ks 3	channels_last speedup, forward 0.849, backward 1.152
# n 1, c 32, h 14, w 14, ks 5	channels_last speedup, forward 0.845, backward 1.205
# n 1, c 32, h 14, w 14, ks 7	channels_last speedup, forward 0.839, backward 1.164
# n 1, c 32, h 28, w 28, ks 2	channels_last speedup, forward 0.847, backward 1.127
# n 1, c 32, h 28, w 28, ks 3	channels_last speedup, forward 0.856, backward 1.108
# n 1, c 32, h 28, w 28, ks 5	channels_last speedup, forward 0.818, backward 1.153
# n 1, c 32, h 28, w 28, ks 7	channels_last speedup, forward 0.853, backward 1.186
# n 1, c 32, h 56, w 56, ks 2	channels_last speedup, forward 0.850, backward 1.153
# n 1, c 32, h 56, w 56, ks 3	channels_last speedup, forward 0.846, backward 1.182
# n 1, c 32, h 56, w 56, ks 5	channels_last speedup, forward 0.794, backward 1.160
# n 1, c 32, h 56, w 56, ks 7	channels_last speedup, forward 0.797, backward 1.193
# n 1, c 32, h 128, w 128, ks 2	channels_last speedup, forward 0.831, backward 1.166
# n 1, c 32, h 128, w 128, ks 3	channels_last speedup, forward 0.834, backward 1.178
# n 1, c 32, h 128, w 128, ks 5	channels_last speedup, forward 0.790, backward 1.181
# n 1, c 32, h 128, w 128, ks 7	channels_last speedup, forward 0.613, backward 1.170
# n 1, c 32, h 256, w 256, ks 2	channels_last speedup, forward 0.718, backward 0.749
# n 1, c 32, h 256, w 256, ks 3	channels_last speedup, forward 0.616, backward 0.755
# n 1, c 32, h 256, w 256, ks 5	channels_last speedup, forward 0.653, backward 0.774
# n 1, c 32, h 256, w 256, ks 7	channels_last speedup, forward 0.517, backward 0.794
# n 1, c 64, h 14, w 14, ks 2	channels_last speedup, forward 0.836, backward 1.172
# n 1, c 64, h 14, w 14, ks 3	channels_last speedup, forward 0.847, backward 1.110
# n 1, c 64, h 14, w 14, ks 5	channels_last speedup, forward 0.833, backward 1.163
# n 1, c 64, h 14, w 14, ks 7	channels_last speedup, forward 0.838, backward 1.162
# n 1, c 64, h 28, w 28, ks 2	channels_last speedup, forward 0.847, backward 1.154
# n 1, c 64, h 28, w 28, ks 3	channels_last speedup, forward 0.828, backward 1.161
# n 1, c 64, h 28, w 28, ks 5	channels_last speedup, forward 0.818, backward 1.179
# n 1, c 64, h 28, w 28, ks 7	channels_last speedup, forward 0.830, backward 1.172
# n 1, c 64, h 56, w 56, ks 2	channels_last speedup, forward 0.835, backward 1.130
# n 1, c 64, h 56, w 56, ks 3	channels_last speedup, forward 0.844, backward 1.151
# n 1, c 64, h 56, w 56, ks 5	channels_last speedup, forward 0.640, backward 1.139
# n 1, c 64, h 56, w 56, ks 7	channels_last speedup, forward 0.629, backward 1.179
# n 1, c 64, h 128, w 128, ks 2	channels_last speedup, forward 0.831, backward 1.039
# n 1, c 64, h 128, w 128, ks 3	channels_last speedup, forward 0.834, backward 1.097
# n 1, c 64, h 128, w 128, ks 5	channels_last speedup, forward 0.683, backward 1.102
# n 1, c 64, h 128, w 128, ks 7	channels_last speedup, forward 0.490, backward 1.121
# n 1, c 64, h 256, w 256, ks 2	channels_last speedup, forward 0.788, backward 0.405
# n 1, c 64, h 256, w 256, ks 3	channels_last speedup, forward 0.495, backward 0.379
# n 1, c 64, h 256, w 256, ks 5	channels_last speedup, forward 0.461, backward 0.375
# n 1, c 64, h 256, w 256, ks 7	channels_last speedup, forward 0.330, backward 0.373
# n 32, c 1, h 14, w 14, ks 2	channels_last speedup, forward 0.944, backward 0.978
# n 32, c 1, h 14, w 14, ks 3	channels_last speedup, forward 0.958, backward 0.970
# n 32, c 1, h 14, w 14, ks 5	channels_last speedup, forward 1.034, backward 1.045
# n 32, c 1, h 14, w 14, ks 7	channels_last speedup, forward 0.876, backward 1.044
# n 32, c 1, h 28, w 28, ks 2	channels_last speedup, forward 0.877, backward 1.042
# n 32, c 1, h 28, w 28, ks 3	channels_last speedup, forward 0.886, backward 1.039
# n 32, c 1, h 28, w 28, ks 5	channels_last speedup, forward 0.870, backward 1.036
# n 32, c 1, h 28, w 28, ks 7	channels_last speedup, forward 0.876, backward 1.034
# n 32, c 1, h 56, w 56, ks 2	channels_last speedup, forward 0.888, backward 1.040
# n 32, c 1, h 56, w 56, ks 3	channels_last speedup, forward 0.874, backward 1.005
# n 32, c 1, h 56, w 56, ks 5	channels_last speedup, forward 0.876, backward 0.989
# n 32, c 1, h 56, w 56, ks 7	channels_last speedup, forward 0.878, backward 1.043
# n 32, c 1, h 128, w 128, ks 2	channels_last speedup, forward 0.870, backward 1.035
# n 32, c 1, h 128, w 128, ks 3	channels_last speedup, forward 0.871, backward 1.035
# n 32, c 1, h 128, w 128, ks 5	channels_last speedup, forward 0.874, backward 1.072
# n 32, c 1, h 128, w 128, ks 7	channels_last speedup, forward 0.872, backward 1.043
# n 32, c 1, h 256, w 256, ks 2	channels_last speedup, forward 0.910, backward 0.990
# n 32, c 1, h 256, w 256, ks 3	channels_last speedup, forward 0.874, backward 1.019
# n 32, c 1, h 256, w 256, ks 5	channels_last speedup, forward 0.875, backward 1.020
# n 32, c 1, h 256, w 256, ks 7	channels_last speedup, forward 0.855, backward 0.999
# n 32, c 32, h 14, w 14, ks 2	channels_last speedup, forward 0.843, backward 1.137
# n 32, c 32, h 14, w 14, ks 3	channels_last speedup, forward 0.836, backward 1.169
# n 32, c 32, h 14, w 14, ks 5	channels_last speedup, forward 0.838, backward 1.214
# n 32, c 32, h 14, w 14, ks 7	channels_last speedup, forward 0.829, backward 1.161
# n 32, c 32, h 28, w 28, ks 2	channels_last speedup, forward 0.843, backward 1.153
# n 32, c 32, h 28, w 28, ks 3	channels_last speedup, forward 0.840, backward 1.162
# n 32, c 32, h 28, w 28, ks 5	channels_last speedup, forward 0.839, backward 1.187
# n 32, c 32, h 28, w 28, ks 7	channels_last speedup, forward 0.834, backward 1.155
# n 32, c 32, h 56, w 56, ks 2	channels_last speedup, forward 0.720, backward 1.095
# n 32, c 32, h 56, w 56, ks 3	channels_last speedup, forward 0.569, backward 1.055
# n 32, c 32, h 56, w 56, ks 5	channels_last speedup, forward 0.458, backward 1.136
# n 32, c 32, h 56, w 56, ks 7	channels_last speedup, forward 0.647, backward 1.143
# n 32, c 32, h 128, w 128, ks 2	channels_last speedup, forward 0.712, backward 1.083
# n 32, c 32, h 128, w 128, ks 3	channels_last speedup, forward 0.454, backward 1.076
# n 32, c 32, h 128, w 128, ks 5	channels_last speedup, forward 0.440, backward 1.092
# n 32, c 32, h 128, w 128, ks 7	channels_last speedup, forward 0.356, backward 1.094
# n 32, c 32, h 256, w 256, ks 2	channels_last speedup, forward 0.716, backward 0.677
# n 32, c 32, h 256, w 256, ks 3	channels_last speedup, forward 0.432, backward 0.651
# n 32, c 32, h 256, w 256, ks 5	channels_last speedup, forward 0.420, backward 0.650
# n 32, c 32, h 256, w 256, ks 7	channels_last speedup, forward 0.326, backward 0.648
# n 32, c 64, h 14, w 14, ks 2	channels_last speedup, forward 0.925, backward 1.162
# n 32, c 64, h 14, w 14, ks 3	channels_last speedup, forward 0.933, backward 1.146
# n 32, c 64, h 14, w 14, ks 5	channels_last speedup, forward 1.017, backward 1.179
# n 32, c 64, h 14, w 14, ks 7	channels_last speedup, forward 0.818, backward 1.188
# n 32, c 64, h 28, w 28, ks 2	channels_last speedup, forward 0.723, backward 1.129
# n 32, c 64, h 28, w 28, ks 3	channels_last speedup, forward 0.658, backward 1.181
# n 32, c 64, h 28, w 28, ks 5	channels_last speedup, forward 0.825, backward 1.222
# n 32, c 64, h 28, w 28, ks 7	channels_last speedup, forward 0.850, backward 1.222
# n 32, c 64, h 56, w 56, ks 2	channels_last speedup, forward 0.727, backward 1.157
# n 32, c 64, h 56, w 56, ks 3	channels_last speedup, forward 0.512, backward 1.149
# n 32, c 64, h 56, w 56, ks 5	channels_last speedup, forward 0.332, backward 1.133
# n 32, c 64, h 56, w 56, ks 7	channels_last speedup, forward 0.488, backward 1.130
# n 32, c 64, h 128, w 128, ks 2	channels_last speedup, forward 0.764, backward 1.116
# n 32, c 64, h 128, w 128, ks 3	channels_last speedup, forward 0.458, backward 1.083
# n 32, c 64, h 128, w 128, ks 5	channels_last speedup, forward 0.405, backward 1.096
# n 32, c 64, h 128, w 128, ks 7	channels_last speedup, forward 0.310, backward 1.099
# n 32, c 64, h 256, w 256, ks 2	channels_last speedup, forward 0.757, backward 0.409
# n 32, c 64, h 256, w 256, ks 3	channels_last speedup, forward 0.415, backward 0.377
# n 32, c 64, h 256, w 256, ks 5	channels_last speedup, forward 0.401, backward 0.371
# n 32, c 64, h 256, w 256, ks 7	channels_last speedup, forward 0.328, backward 0.367
# n 64, c 1, h 14, w 14, ks 2	channels_last speedup, forward 0.955, backward 0.971
# n 64, c 1, h 14, w 14, ks 3	channels_last speedup, forward 0.958, backward 0.997
# n 64, c 1, h 14, w 14, ks 5	channels_last speedup, forward 0.950, backward 0.993
# n 64, c 1, h 14, w 14, ks 7	channels_last speedup, forward 1.003, backward 1.043
# n 64, c 1, h 28, w 28, ks 2	channels_last speedup, forward 0.871, backward 1.049
# n 64, c 1, h 28, w 28, ks 3	channels_last speedup, forward 0.878, backward 1.049
# n 64, c 1, h 28, w 28, ks 5	channels_last speedup, forward 0.873, backward 1.033
# n 64, c 1, h 28, w 28, ks 7	channels_last speedup, forward 0.879, backward 1.053
# n 64, c 1, h 56, w 56, ks 2	channels_last speedup, forward 0.872, backward 1.043
# n 64, c 1, h 56, w 56, ks 3	channels_last speedup, forward 0.857, backward 1.041
# n 64, c 1, h 56, w 56, ks 5	channels_last speedup, forward 0.875, backward 1.041
# n 64, c 1, h 56, w 56, ks 7	channels_last speedup, forward 0.874, backward 1.034
# n 64, c 1, h 128, w 128, ks 2	channels_last speedup, forward 0.871, backward 0.988
# n 64, c 1, h 128, w 128, ks 3	channels_last speedup, forward 0.877, backward 1.022
# n 64, c 1, h 128, w 128, ks 5	channels_last speedup, forward 0.872, backward 1.034
# n 64, c 1, h 128, w 128, ks 7	channels_last speedup, forward 0.894, backward 1.032
# n 64, c 1, h 256, w 256, ks 2	channels_last speedup, forward 0.981, backward 1.010
# n 64, c 1, h 256, w 256, ks 3	channels_last speedup, forward 0.955, backward 1.008
# n 64, c 1, h 256, w 256, ks 5	channels_last speedup, forward 0.949, backward 1.003
# n 64, c 1, h 256, w 256, ks 7	channels_last speedup, forward 0.951, backward 1.008
# n 64, c 32, h 14, w 14, ks 2	channels_last speedup, forward 0.824, backward 1.196
# n 64, c 32, h 14, w 14, ks 3	channels_last speedup, forward 0.840, backward 1.173
# n 64, c 32, h 14, w 14, ks 5	channels_last speedup, forward 0.837, backward 1.181
# n 64, c 32, h 14, w 14, ks 7	channels_last speedup, forward 0.833, backward 1.167
# n 64, c 32, h 28, w 28, ks 2	channels_last speedup, forward 0.698, backward 1.073
# n 64, c 32, h 28, w 28, ks 3	channels_last speedup, forward 0.687, backward 1.171
# n 64, c 32, h 28, w 28, ks 5	channels_last speedup, forward 0.823, backward 1.216
# n 64, c 32, h 28, w 28, ks 7	channels_last speedup, forward 0.839, backward 1.209
# n 64, c 32, h 56, w 56, ks 2	channels_last speedup, forward 0.691, backward 1.106
# n 64, c 32, h 56, w 56, ks 3	channels_last speedup, forward 0.501, backward 1.117
# n 64, c 32, h 56, w 56, ks 5	channels_last speedup, forward 0.378, backward 1.142
# n 64, c 32, h 56, w 56, ks 7	channels_last speedup, forward 0.591, backward 1.120
# n 64, c 32, h 128, w 128, ks 2	channels_last speedup, forward 0.711, backward 1.087
# n 64, c 32, h 128, w 128, ks 3	channels_last speedup, forward 0.434, backward 1.079
# n 64, c 32, h 128, w 128, ks 5	channels_last speedup, forward 0.418, backward 1.098
# n 64, c 32, h 128, w 128, ks 7	channels_last speedup, forward 0.338, backward 1.108
# n 64, c 32, h 256, w 256, ks 2	channels_last speedup, forward 0.712, backward 0.676
# n 64, c 32, h 256, w 256, ks 3	channels_last speedup, forward 0.404, backward 0.638
# n 64, c 32, h 256, w 256, ks 5	channels_last speedup, forward 0.409, backward 0.645
# n 64, c 32, h 256, w 256, ks 7	channels_last speedup, forward 0.324, backward 0.643
# n 64, c 64, h 14, w 14, ks 2	channels_last speedup, forward 0.930, backward 1.073
# n 64, c 64, h 14, w 14, ks 3	channels_last speedup, forward 0.895, backward 1.145
# n 64, c 64, h 14, w 14, ks 5	channels_last speedup, forward 0.994, backward 1.173
# n 64, c 64, h 14, w 14, ks 7	channels_last speedup, forward 0.836, backward 1.171
# n 64, c 64, h 28, w 28, ks 2	channels_last speedup, forward 0.646, backward 1.179
# n 64, c 64, h 28, w 28, ks 3	channels_last speedup, forward 0.536, backward 1.163
# n 64, c 64, h 28, w 28, ks 5	channels_last speedup, forward 0.484, backward 1.210
# n 64, c 64, h 28, w 28, ks 7	channels_last speedup, forward 0.785, backward 1.206
# n 64, c 64, h 56, w 56, ks 2	channels_last speedup, forward 0.691, backward 1.140
# n 64, c 64, h 56, w 56, ks 3	channels_last speedup, forward 0.447, backward 1.112
# n 64, c 64, h 56, w 56, ks 5	channels_last speedup, forward 0.288, backward 1.145
# n 64, c 64, h 56, w 56, ks 7	channels_last speedup, forward 0.430, backward 1.133
# n 64, c 64, h 128, w 128, ks 2	channels_last speedup, forward 0.760, backward 1.112
# n 64, c 64, h 128, w 128, ks 3	channels_last speedup, forward 0.440, backward 1.041
# n 64, c 64, h 128, w 128, ks 5	channels_last speedup, forward 0.392, backward 1.089
# n 64, c 64, h 128, w 128, ks 7	channels_last speedup, forward 0.313, backward 1.094
# n 64, c 64, h 256, w 256, ks 2	channels_last speedup, forward 0.755, backward 0.407
# n 64, c 64, h 256, w 256, ks 3	channels_last speedup, forward 0.396, backward 0.374
# n 64, c 64, h 256, w 256, ks 5	channels_last speedup, forward 0.393, backward 0.365
# n 64, c 64, h 256, w 256, ks 7	channels_last speedup, forward 0.330, backward 0.363

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.distplot(fs, bins=40)
plt.show() 

sns.distplot(bs, bins=40)
plt.show()
