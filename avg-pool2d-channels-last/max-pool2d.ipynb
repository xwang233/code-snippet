# %%
import torch 
import time 

print(torch.__version__)

dtype=torch.half
warm_up = 100 
n_iter = 1000

fs = [] 
bs = []

for n in (1, 32, 64): 
    for c in (1, 32, 64): 
        for h in (14, 28, 56, 128, 256): 
            w = h
            for ks in (2, 3, 5, 7): 
                torch.cuda.empty_cache() 

                print(f'n {n}, c {c}, h {h}, w {w}, ks {ks}', end='\t')

                a = torch.randn(n, c, h, w, dtype=dtype, device='cuda').contiguous(memory_format=torch.channels_last)
                ref_a = a.clone().contiguous() 

                a.requires_grad_() 
                ref_a.requires_grad_() 

                pool = torch.nn.MaxPool2d(ks).cuda()
                ref_pool = torch.nn.MaxPool2d(ks).cuda()

                out = pool(a)
                ref_out = ref_pool(ref_a)

                grad = torch.ones_like(out)
                out.backward(grad, retain_graph=True)
                ref_out.backward(grad, retain_graph=True)

                assert((out==ref_out).all().item())
                assert((a.grad==ref_a.grad).all().item())

                ########## warm up ##########
                for _ in range(warm_up): 
                    out = pool(a)
                    ref_out = ref_pool(ref_a)
                    out.backward(grad, retain_graph=True)
                    ref_out.backward(grad, retain_graph=True)

                ########## channels_last forward ##########
                torch.cuda.synchronize() 
                ts = time.time() 

                for _ in range(n_iter): 
                    out = pool(a)
                    torch.cuda.synchronize() 

                t_channels_last_forward = (time.time() - ts) / n_iter

                ########## contiguous forward ##########
                torch.cuda.synchronize()
                ts = time.time() 

                for _ in range(n_iter): 
                    ref_out = ref_pool(a)
                    torch.cuda.synchronize() 

                t_contiguous_forward = (time.time() - ts) / n_iter

                ########## channels_last backward ##########
                torch.cuda.synchronize() 
                ts = time.time() 

                for _ in range(n_iter): 
                    out.backward(grad, retain_graph=True)
                    torch.cuda.synchronize() 

                t_channels_last_backward = (time.time() - ts) / n_iter

                ########## contiguous backward ##########
                torch.cuda.synchronize()
                ts = time.time() 

                for _ in range(n_iter): 
                    ref_out.backward(grad, retain_graph=True)
                    torch.cuda.synchronize() 

                t_contiguous_backward = (time.time() - ts) / n_iter
                
                ########## stat ##########
                forward_speedup = t_contiguous_forward/t_channels_last_forward
                backward_speedup = t_contiguous_backward/t_channels_last_backward
                fs.append(forward_speedup)
                bs.append(backward_speedup)
                
                ########## print ##########
                print('channels_last speedup, forward {:.3f}, backward {:.3f}'.format(
                    forward_speedup, backward_speedup
                ))
# Out:
# 1.6.0a0+0a8fd79
# n 1, c 1, h 14, w 14, ks 2	channels_last speedup, forward 0.962, backward 1.008
# n 1, c 1, h 14, w 14, ks 3	channels_last speedup, forward 0.953, backward 0.973
# n 1, c 1, h 14, w 14, ks 5	channels_last speedup, forward 0.956, backward 0.992
# n 1, c 1, h 14, w 14, ks 7	channels_last speedup, forward 1.008, backward 1.068
# n 1, c 1, h 28, w 28, ks 2	channels_last speedup, forward 0.872, backward 0.884
# n 1, c 1, h 28, w 28, ks 3	channels_last speedup, forward 1.171, backward 1.081
# n 1, c 1, h 28, w 28, ks 5	channels_last speedup, forward 0.869, backward 1.054
# n 1, c 1, h 28, w 28, ks 7	channels_last speedup, forward 0.865, backward 1.035
# n 1, c 1, h 56, w 56, ks 2	channels_last speedup, forward 0.868, backward 1.053
# n 1, c 1, h 56, w 56, ks 3	channels_last speedup, forward 0.860, backward 1.056
# n 1, c 1, h 56, w 56, ks 5	channels_last speedup, forward 0.808, backward 1.050
# n 1, c 1, h 56, w 56, ks 7	channels_last speedup, forward 0.869, backward 1.048
# n 1, c 1, h 128, w 128, ks 2	channels_last speedup, forward 0.861, backward 1.051
# n 1, c 1, h 128, w 128, ks 3	channels_last speedup, forward 0.877, backward 1.053
# n 1, c 1, h 128, w 128, ks 5	channels_last speedup, forward 0.883, backward 1.041
# n 1, c 1, h 128, w 128, ks 7	channels_last speedup, forward 0.883, backward 0.985
# n 1, c 1, h 256, w 256, ks 2	channels_last speedup, forward 0.875, backward 1.083
# n 1, c 1, h 256, w 256, ks 3	channels_last speedup, forward 0.872, backward 1.042
# n 1, c 1, h 256, w 256, ks 5	channels_last speedup, forward 0.871, backward 1.059
# n 1, c 1, h 256, w 256, ks 7	channels_last speedup, forward 0.877, backward 1.046
# n 1, c 32, h 14, w 14, ks 2	channels_last speedup, forward 0.868, backward 1.051
# n 1, c 32, h 14, w 14, ks 3	channels_last speedup, forward 0.848, backward 1.045
# n 1, c 32, h 14, w 14, ks 5	channels_last speedup, forward 0.856, backward 1.037
# n 1, c 32, h 14, w 14, ks 7	channels_last speedup, forward 0.810, backward 1.072
# n 1, c 32, h 28, w 28, ks 2	channels_last speedup, forward 0.853, backward 1.056
# n 1, c 32, h 28, w 28, ks 3	channels_last speedup, forward 0.863, backward 1.042
# n 1, c 32, h 28, w 28, ks 5	channels_last speedup, forward 0.887, backward 1.051
# n 1, c 32, h 28, w 28, ks 7	channels_last speedup, forward 0.861, backward 1.103
# n 1, c 32, h 56, w 56, ks 2	channels_last speedup, forward 0.884, backward 1.140
# n 1, c 32, h 56, w 56, ks 3	channels_last speedup, forward 0.871, backward 1.113
# n 1, c 32, h 56, w 56, ks 5	channels_last speedup, forward 0.885, backward 1.097
# n 1, c 32, h 56, w 56, ks 7	channels_last speedup, forward 0.883, backward 1.109
# n 1, c 32, h 128, w 128, ks 2	channels_last speedup, forward 0.867, backward 1.080
# n 1, c 32, h 128, w 128, ks 3	channels_last speedup, forward 0.865, backward 1.099
# n 1, c 32, h 128, w 128, ks 5	channels_last speedup, forward 0.878, backward 1.099
# n 1, c 32, h 128, w 128, ks 7	channels_last speedup, forward 0.918, backward 1.109
# n 1, c 32, h 256, w 256, ks 2	channels_last speedup, forward 0.924, backward 1.004
# n 1, c 32, h 256, w 256, ks 3	channels_last speedup, forward 0.919, backward 1.000
# n 1, c 32, h 256, w 256, ks 5	channels_last speedup, forward 0.999, backward 1.009
# n 1, c 32, h 256, w 256, ks 7	channels_last speedup, forward 1.004, backward 1.002
# n 1, c 64, h 14, w 14, ks 2	channels_last speedup, forward 0.966, backward 1.177
# n 1, c 64, h 14, w 14, ks 3	channels_last speedup, forward 0.822, backward 1.101
# n 1, c 64, h 14, w 14, ks 5	channels_last speedup, forward 0.865, backward 1.093
# n 1, c 64, h 14, w 14, ks 7	channels_last speedup, forward 0.872, backward 1.104
# n 1, c 64, h 28, w 28, ks 2	channels_last speedup, forward 0.825, backward 1.087
# n 1, c 64, h 28, w 28, ks 3	channels_last speedup, forward 0.865, backward 1.096
# n 1, c 64, h 28, w 28, ks 5	channels_last speedup, forward 0.875, backward 1.100
# n 1, c 64, h 28, w 28, ks 7	channels_last speedup, forward 0.870, backward 1.091
# n 1, c 64, h 56, w 56, ks 2	channels_last speedup, forward 0.864, backward 1.103
# n 1, c 64, h 56, w 56, ks 3	channels_last speedup, forward 0.867, backward 1.095
# n 1, c 64, h 56, w 56, ks 5	channels_last speedup, forward 0.938, backward 1.089
# n 1, c 64, h 56, w 56, ks 7	channels_last speedup, forward 0.938, backward 1.094
# n 1, c 64, h 128, w 128, ks 2	channels_last speedup, forward 0.866, backward 1.061
# n 1, c 64, h 128, w 128, ks 3	channels_last speedup, forward 0.861, backward 1.015
# n 1, c 64, h 128, w 128, ks 5	channels_last speedup, forward 0.928, backward 1.059
# n 1, c 64, h 128, w 128, ks 7	channels_last speedup, forward 0.963, backward 1.080
# n 1, c 64, h 256, w 256, ks 2	channels_last speedup, forward 0.986, backward 0.978
# n 1, c 64, h 256, w 256, ks 3	channels_last speedup, forward 0.999, backward 1.003
# n 1, c 64, h 256, w 256, ks 5	channels_last speedup, forward 0.994, backward 1.006
# n 1, c 64, h 256, w 256, ks 7	channels_last speedup, forward 0.997, backward 1.001
# n 32, c 1, h 14, w 14, ks 2	channels_last speedup, forward 0.980, backward 1.183
# n 32, c 1, h 14, w 14, ks 3	channels_last speedup, forward 0.873, backward 1.026
# n 32, c 1, h 14, w 14, ks 5	channels_last speedup, forward 0.868, backward 1.022
# n 32, c 1, h 14, w 14, ks 7	channels_last speedup, forward 0.871, backward 1.044
# n 32, c 1, h 28, w 28, ks 2	channels_last speedup, forward 0.871, backward 1.055
# n 32, c 1, h 28, w 28, ks 3	channels_last speedup, forward 0.879, backward 1.047
# n 32, c 1, h 28, w 28, ks 5	channels_last speedup, forward 0.875, backward 1.057
# n 32, c 1, h 28, w 28, ks 7	channels_last speedup, forward 0.869, backward 1.049
# n 32, c 1, h 56, w 56, ks 2	channels_last speedup, forward 0.867, backward 1.013
# n 32, c 1, h 56, w 56, ks 3	channels_last speedup, forward 0.866, backward 1.043
# n 32, c 1, h 56, w 56, ks 5	channels_last speedup, forward 0.884, backward 1.058
# n 32, c 1, h 56, w 56, ks 7	channels_last speedup, forward 0.872, backward 1.054
# n 32, c 1, h 128, w 128, ks 2	channels_last speedup, forward 0.870, backward 1.063
# n 32, c 1, h 128, w 128, ks 3	channels_last speedup, forward 0.883, backward 1.027
# n 32, c 1, h 128, w 128, ks 5	channels_last speedup, forward 0.876, backward 1.049
# n 32, c 1, h 128, w 128, ks 7	channels_last speedup, forward 0.878, backward 1.056
# n 32, c 1, h 256, w 256, ks 2	channels_last speedup, forward 0.923, backward 0.998
# n 32, c 1, h 256, w 256, ks 3	channels_last speedup, forward 0.863, backward 1.009
# n 32, c 1, h 256, w 256, ks 5	channels_last speedup, forward 0.877, backward 1.006
# n 32, c 1, h 256, w 256, ks 7	channels_last speedup, forward 0.879, backward 1.010
# n 32, c 32, h 14, w 14, ks 2	channels_last speedup, forward 0.873, backward 1.075
# n 32, c 32, h 14, w 14, ks 3	channels_last speedup, forward 0.869, backward 1.003
# n 32, c 32, h 14, w 14, ks 5	channels_last speedup, forward 0.858, backward 1.056
# n 32, c 32, h 14, w 14, ks 7	channels_last speedup, forward 0.868, backward 1.018
# n 32, c 32, h 28, w 28, ks 2	channels_last speedup, forward 0.850, backward 1.006
# n 32, c 32, h 28, w 28, ks 3	channels_last speedup, forward 0.859, backward 1.043
# n 32, c 32, h 28, w 28, ks 5	channels_last speedup, forward 0.860, backward 1.047
# n 32, c 32, h 28, w 28, ks 7	channels_last speedup, forward 0.861, backward 1.032
# n 32, c 32, h 56, w 56, ks 2	channels_last speedup, forward 0.968, backward 1.005
# n 32, c 32, h 56, w 56, ks 3	channels_last speedup, forward 0.962, backward 0.996
# n 32, c 32, h 56, w 56, ks 5	channels_last speedup, forward 1.003, backward 1.008
# n 32, c 32, h 56, w 56, ks 7	channels_last speedup, forward 1.006, backward 1.002
# n 32, c 32, h 128, w 128, ks 2	channels_last speedup, forward 0.998, backward 1.000
# n 32, c 32, h 128, w 128, ks 3	channels_last speedup, forward 0.998, backward 0.998
# n 32, c 32, h 128, w 128, ks 5	channels_last speedup, forward 0.999, backward 0.997
# n 32, c 32, h 128, w 128, ks 7	channels_last speedup, forward 0.999, backward 1.003
# n 32, c 32, h 256, w 256, ks 2	channels_last speedup, forward 1.000, backward 1.000
# n 32, c 32, h 256, w 256, ks 3	channels_last speedup, forward 0.998, backward 1.000
# n 32, c 32, h 256, w 256, ks 5	channels_last speedup, forward 1.000, backward 1.000
# n 32, c 32, h 256, w 256, ks 7	channels_last speedup, forward 0.999, backward 1.001
# n 32, c 64, h 14, w 14, ks 2	channels_last speedup, forward 0.947, backward 0.982
# n 32, c 64, h 14, w 14, ks 3	channels_last speedup, forward 0.942, backward 0.974
# n 32, c 64, h 14, w 14, ks 5	channels_last speedup, forward 1.028, backward 0.996
# n 32, c 64, h 14, w 14, ks 7	channels_last speedup, forward 0.937, backward 0.971
# n 32, c 64, h 28, w 28, ks 2	channels_last speedup, forward 0.995, backward 1.036
# n 32, c 64, h 28, w 28, ks 3	channels_last speedup, forward 0.938, backward 1.027
# n 32, c 64, h 28, w 28, ks 5	channels_last speedup, forward 0.872, backward 1.017
# n 32, c 64, h 28, w 28, ks 7	channels_last speedup, forward 0.856, backward 1.019
# n 32, c 64, h 56, w 56, ks 2	channels_last speedup, forward 0.989, backward 0.994
# n 32, c 64, h 56, w 56, ks 3	channels_last speedup, forward 0.962, backward 1.001
# n 32, c 64, h 56, w 56, ks 5	channels_last speedup, forward 0.996, backward 0.999
# n 32, c 64, h 56, w 56, ks 7	channels_last speedup, forward 0.998, backward 1.002
# n 32, c 64, h 128, w 128, ks 2	channels_last speedup, forward 0.999, backward 1.004
# n 32, c 64, h 128, w 128, ks 3	channels_last speedup, forward 0.998, backward 1.000
# n 32, c 64, h 128, w 128, ks 5	channels_last speedup, forward 1.000, backward 1.004
# n 32, c 64, h 128, w 128, ks 7	channels_last speedup, forward 1.003, backward 1.009
# n 32, c 64, h 256, w 256, ks 2	channels_last speedup, forward 1.001, backward 1.000
# n 32, c 64, h 256, w 256, ks 3	channels_last speedup, forward 0.999, backward 1.000
# n 32, c 64, h 256, w 256, ks 5	channels_last speedup, forward 1.001, backward 1.000
# n 32, c 64, h 256, w 256, ks 7	channels_last speedup, forward 1.000, backward 1.000
# n 64, c 1, h 14, w 14, ks 2	channels_last speedup, forward 0.955, backward 1.043
# n 64, c 1, h 14, w 14, ks 3	channels_last speedup, forward 0.916, backward 1.060
# n 64, c 1, h 14, w 14, ks 5	channels_last speedup, forward 0.875, backward 1.041
# n 64, c 1, h 14, w 14, ks 7	channels_last speedup, forward 0.871, backward 1.058
# n 64, c 1, h 28, w 28, ks 2	channels_last speedup, forward 0.862, backward 1.078
# n 64, c 1, h 28, w 28, ks 3	channels_last speedup, forward 0.873, backward 1.043
# n 64, c 1, h 28, w 28, ks 5	channels_last speedup, forward 0.880, backward 1.051
# n 64, c 1, h 28, w 28, ks 7	channels_last speedup, forward 0.869, backward 1.072
# n 64, c 1, h 56, w 56, ks 2	channels_last speedup, forward 0.883, backward 1.057
# n 64, c 1, h 56, w 56, ks 3	channels_last speedup, forward 0.885, backward 1.050
# n 64, c 1, h 56, w 56, ks 5	channels_last speedup, forward 0.879, backward 1.077
# n 64, c 1, h 56, w 56, ks 7	channels_last speedup, forward 0.875, backward 1.074
# n 64, c 1, h 128, w 128, ks 2	channels_last speedup, forward 0.878, backward 1.009
# n 64, c 1, h 128, w 128, ks 3	channels_last speedup, forward 0.860, backward 1.048
# n 64, c 1, h 128, w 128, ks 5	channels_last speedup, forward 0.882, backward 1.048
# n 64, c 1, h 128, w 128, ks 7	channels_last speedup, forward 0.870, backward 1.029
# n 64, c 1, h 256, w 256, ks 2	channels_last speedup, forward 0.979, backward 1.002
# n 64, c 1, h 256, w 256, ks 3	channels_last speedup, forward 0.973, backward 1.013
# n 64, c 1, h 256, w 256, ks 5	channels_last speedup, forward 0.958, backward 1.002
# n 64, c 1, h 256, w 256, ks 7	channels_last speedup, forward 0.954, backward 0.999
# n 64, c 32, h 14, w 14, ks 2	channels_last speedup, forward 0.845, backward 1.050
# n 64, c 32, h 14, w 14, ks 3	channels_last speedup, forward 0.864, backward 1.087
# n 64, c 32, h 14, w 14, ks 5	channels_last speedup, forward 0.841, backward 1.031
# n 64, c 32, h 14, w 14, ks 7	channels_last speedup, forward 0.851, backward 1.038
# n 64, c 32, h 28, w 28, ks 2	channels_last speedup, forward 0.900, backward 1.026
# n 64, c 32, h 28, w 28, ks 3	channels_last speedup, forward 0.942, backward 1.034
# n 64, c 32, h 28, w 28, ks 5	channels_last speedup, forward 0.877, backward 1.033
# n 64, c 32, h 28, w 28, ks 7	channels_last speedup, forward 0.863, backward 1.036
# n 64, c 32, h 56, w 56, ks 2	channels_last speedup, forward 0.990, backward 1.001
# n 64, c 32, h 56, w 56, ks 3	channels_last speedup, forward 0.973, backward 1.002
# n 64, c 32, h 56, w 56, ks 5	channels_last speedup, forward 0.998, backward 1.003
# n 64, c 32, h 56, w 56, ks 7	channels_last speedup, forward 0.998, backward 1.001
# n 64, c 32, h 128, w 128, ks 2	channels_last speedup, forward 1.000, backward 1.004
# n 64, c 32, h 128, w 128, ks 3	channels_last speedup, forward 0.999, backward 1.000
# n 64, c 32, h 128, w 128, ks 5	channels_last speedup, forward 0.999, backward 1.000
# n 64, c 32, h 128, w 128, ks 7	channels_last speedup, forward 0.999, backward 1.000
# n 64, c 32, h 256, w 256, ks 2	channels_last speedup, forward 1.000, backward 1.000
# n 64, c 32, h 256, w 256, ks 3	channels_last speedup, forward 1.000, backward 1.000
# n 64, c 32, h 256, w 256, ks 5	channels_last speedup, forward 1.000, backward 1.000
# n 64, c 32, h 256, w 256, ks 7	channels_last speedup, forward 1.000, backward 1.001
# n 64, c 64, h 14, w 14, ks 2	channels_last speedup, forward 0.949, backward 0.986
# n 64, c 64, h 14, w 14, ks 3	channels_last speedup, forward 0.941, backward 1.002
# n 64, c 64, h 14, w 14, ks 5	channels_last speedup, forward 0.997, backward 1.027
# n 64, c 64, h 14, w 14, ks 7	channels_last speedup, forward 0.878, backward 0.991
# n 64, c 64, h 28, w 28, ks 2	channels_last speedup, forward 1.005, backward 1.042
# n 64, c 64, h 28, w 28, ks 3	channels_last speedup, forward 0.969, backward 1.009
# n 64, c 64, h 28, w 28, ks 5	channels_last speedup, forward 0.963, backward 1.016
# n 64, c 64, h 28, w 28, ks 7	channels_last speedup, forward 0.944, backward 1.018
# n 64, c 64, h 56, w 56, ks 2	channels_last speedup, forward 0.999, backward 0.994
# n 64, c 64, h 56, w 56, ks 3	channels_last speedup, forward 0.998, backward 1.001
# n 64, c 64, h 56, w 56, ks 5	channels_last speedup, forward 0.999, backward 1.001
# n 64, c 64, h 56, w 56, ks 7	channels_last speedup, forward 0.999, backward 1.001
# n 64, c 64, h 128, w 128, ks 2	channels_last speedup, forward 0.997, backward 1.000
# n 64, c 64, h 128, w 128, ks 3	channels_last speedup, forward 1.002, backward 1.000
# n 64, c 64, h 128, w 128, ks 5	channels_last speedup, forward 1.003, backward 1.000
# n 64, c 64, h 128, w 128, ks 7	channels_last speedup, forward 1.000, backward 1.004
# n 64, c 64, h 256, w 256, ks 2	channels_last speedup, forward 1.000, backward 1.000
# n 64, c 64, h 256, w 256, ks 3	channels_last speedup, forward 1.000, backward 1.000
# n 64, c 64, h 256, w 256, ks 5	channels_last speedup, forward 1.000, backward 1.000
# n 64, c 64, h 256, w 256, ks 7	channels_last speedup, forward 1.000, backward 1.000

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.distplot(fs, bins=40)
plt.show() 

sns.distplot(bs, bins=40)
plt.show()
